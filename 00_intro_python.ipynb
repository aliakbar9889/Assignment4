# %% [markdown]
# <a href="https://colab.research.google.com/github/aliakbar9889/Assignment4/blob/main/00_intro_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 01_add_two_numbers.

print("ADDITION OF TWO NUMBERS")

def sum ():
    Num1 = int(input('Enter Your First Number:'))
    Num2 = int(input('Enter Your Second Number:'))
    sum = int(Num1 + Num2)
    print(f"Your Addition of {Num1} & {Num2} is {sum}")

if __name__ == "__main__":
 sum()
# Out:
# 01_add_two_numbers
# Enter Your First Number:5
# Enter Your Second Number:5
# Your Addition of 5 & 5 is 10

# %%
# 02_agreement_bot

print("AGREEMENT BOT")
def bot():
  animal = str(input('Who is Your Favourite Animal:'))
  ans = print(f"My Favourite Animal is also {animal}")

if __name__ == "__main__":
 bot()
# Out:
# AGREEMENT BOT
# Who is Your Favourite Animal:uja
# My Favourite Animal is also uja

# %%
# 03_fehrenheit_to_celsius

print("Fehrenheit To Celsius Converter")
def convert():
  fehrenheit = float(input('Enter Your Fehrenheit Value:'))
  celsius = (fehrenheit - 32) * 5.0/9.0
  print(f'Your Celsius Value of {fehrenheit} is {celsius}')

if __name__ == "__main__":
 convert()
# Out:
# Fehrenheit To Celsius Converter
# Enter Your Fehrenheit Value:25
# Your Celsius Value of 25.0 is -3.888888888888889

# %%
# 04_how_old_are_they

print("How Old Are They?")

def old():
    anton : int = 21
    beth : int = 6 + anton
    chen : int = 20 + beth
    drew  : int= chen + anton
    ethan : int = chen

    print(f'Anthon is {anton} year old')
    print(f'Beth is {beth} year old')
    print(f'Chen is {chen} year old')
    print(f'Drew is {drew} year old')
    print(f'Ethan is {ethan} year old')


if __name__ == "__main__":
  old()
# Out:
# How Old Are They?
# 04_how_old_are_they
# Anthon is 21 year old
# Beth is 27 year old
# Chen is 47 year old
# Drew is 68 year old
# Ethan is 47 year old

# %%
# 05_triangle_perimeter
def perimeter():
  print("Calculation of Perimeter of Triangle")
  side1 : float = float(input('Enter Your First Side of Triangle'))
  side2 : float = float(input('Enter Your Second Side of Triangle'))
  side3 : float = float(input('Enter Your Third Side of Triangle'))
  peri : float = float(side1 + side2 + side3)

  print(f'The perimeter of triangle is {peri}')

if __name__ == '__main__':
    perimeter()
# Out:
# Calculation of Perimeter of Triangle
# Enter Your First Side of Triangle2
# Enter Your Second Side of Triangle2
# Enter Your Third Side of Triangle2
# The perimeter of triangle is 6.0

# %%
# 06_square_number

def square():
  print("Square Of The Number")
  num : int = int(input('Enter a number:'))
  print(f'The Square of {num} is {num * num}')

if __name__ == '__main__':
    square()
# Out:
# Square Of The Number
# Enter a number:2
# The Square of 2 is 4
