# %% [markdown]
# <a href="https://colab.research.google.com/github/aliakbar9889/Assignment4/blob/main/01_expressions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 01_dicesimulator

import random

print("DICESIMULATOR")

def roll():
    dice1: int = random.randint(1, 6)
    dice2: int = random.randint(1, 6)
    total: int = dice1 + dice2
    print(f'Two Dice is : {total}')
    return dice1, dice2

def main():
    dice1: int = 10
    print("die1 in main() starts as: " + str(dice1))
    die1,die2 = roll()
    print(f'Rolled Dice : {die1},{die2}')
    die1,die2 = roll()
    print(f'Rolled Dice : {die1},{die2}')
    die1,die2 = roll()
    print(f'Rolled Dice : {die1},{die2}')

    print("die1 in main() is: " + str(die1))

if __name__ == '__main__':
    main()
# Out:
# DICESIMULATOR
# die1 in main() starts as: 10
# Two Dice is : 6
# Rolled Dice : 5,1
# Two Dice is : 5
# Rolled Dice : 3,2
# Two Dice is : 5
# Rolled Dice : 4,1
# die1 in main() is: 4

# %%
# 02_e=mc2

print("Einstein Formula For Energy")

def energy():
  c: float = 299792458
  m: float = float((input('Enter Your Mass in kg :')))

  print('e = m * C^2')
  print('m = ' + str(m) + "kg")
  print('c = ' + str(c) + 'm/s')
  print("======================")
  print("e = " + str(m * c ** 2) + " Joules")

if __name__ == '__main__':
    energy()
# Out:
# Eintein Formula For Energy
# Enter Your Mass in kg :100
# e = m * C^2
# m = 100.0kg
# c = 299792458m/s
# ======================
# e = 8.987551787368176e+18 Joules

# %%
# 03_feet_to_inches

print("FEETS TO INCHES CONVERTER")

def main():
  inch: int = 12

  feet:int = int(input('Enter Your Feet:'))
  print("There are " + str(feet * inch) + " inches in " + str(feet) + ' feet')

if __name__ == '__main__':
    main()
# Out:
# FEETS TO INCHES CONVERTER
# Enter Your Feet:10
# There are 120 inches in 10 feet

# %%
# 04_pythagorean_theorem
import math
print("PYTHOGOREAN THEOREM")

def main():
  AB : float = float(input('Enter The length of Side AB:'))
  AC : float = float(input("Enter The length of Side AC:"))
  BC : float = math.sqrt(AB ** 2 + AC ** 2)
  print("SIDE AB = " + str(AB))
  print("SIDE AC = " + str(AC))
  print("SIDE BC (which required) = " + str(BC))

if __name__ == '__main__':
    main()
# Out:
# PYTHOGOREAN THEOREM
# Enter The length of Side AB:10
# Enter The length of Side AC:25
# SIDE AB = 10.0
# SIDE AC = 25.0
# SIDE BC (which required) = 26.92582403567252

# %%
# 05_remainder_division
print("REMAINDER DIVISION")

def main():
  num1 : int = int(input('Enter your first number :'))
  num2 : int = int(input('Enter your second number :'))

  quotient : int = num1 // num2
  remainder : int = num1 % num2

  print(f'The Quotient is {quotient} & Remainder is {remainder} for {num1} divided by {num2}')

  if remainder == 0:
     print(f'{num1} is completely divisible by {num2}.')
  else:
     print(f'{num1} is not completely divisible by {num2}.')

if __name__ == '__main__':
    main()
# Out:
# REMAINDER DIVISION
# Enter your first number :12
# Enter your second number :2
# The Quotient is 6 & Remainder is 0 for 12 divided by 2
# 12 is completely divisible by 2.

# %%
# 06_rolldice
import random
print("ROLL DICE")
def main():
  d1 : int = random.randint(1,6)
  d2 : int = random.randint(1,6)
  print(f'Total of Two Dice is : {d1+d2}')
if __name__ == '__main__':
    main()
# Out:
# ROLL DICE
# Total of Two Dice is : 9

# %%
# 06_seconds_in_year

print("Seconds in a Year")

def main():
  seconds_in_minute : int = 60
  seconds_in_hour : int = 60 * 60
  seconds_in_day : int = 60 * 60 * 24
  seconds_in_year: int = seconds_in_day * 365
  print(f'There are {seconds_in_year} in a year.')

if __name__ == '__main__':
    main()
# Out:
# Seconds in a Year
# There are 31536000 in a year.

# %%
# 07_tiny_mad_lib

print("TINY MAD LIBS")

def main():
  noun: str = input('Enter a Noun: ')
  verb: str = input('Enter a verb: ')
  adj : str = input('Enter an adjective:' )
  print(f'Do you {verb} {adj} in {noun}?')

if __name__ == '__main__':
    main()
# Out:
# TINY MAD LIBS
# Enter a Noun: ali
# Enter a verb: ali
# Enter an adjective:ali
# Do you ali ali in ali?
